# %%
from sentinelsat import SentinelAPI, read_geojson,geojson_to_wkt

# %%
from datetime import date

# %%
ds_path = r'D:\School\Strathclyde\EF_900\Data\SentinelSatData\Rice\S1' #download storage path

# %%
username = 'kleffy'
password = 'badboy12@ADL'
#url = 'https://earthexplorer.usgs.gov/'

api = SentinelAPI(username, password)

# %%
#get area of interest
footprint = geojson_to_wkt(read_geojson(r'olarm_farms_footprint.geojson'))

# %%
#query resultset
products = api.query(footprint,
                     date=('20190301', date(2019, 7, 30)),
                     platformname='Sentinel-1',
                     #processinglevel='Level-1C',
                     #cloudcoverpercentage=(0, 30)
                    )
print(len(products))
# Out:
# 89

# %%
#downloading the data
for i in products:
    p_data = api.get_product_odata(i)
    if 'IW_GRDH' in p_data['title']:
        #api.get_product_odata(i)
        api.download(i, ds_path)
# Out:
# Product a59ebe16-ea3e-4e23-ae99-e8f32244e5e8 is not online. Triggering retrieval from long term archive.
# Product c5f6f79c-0624-4539-b9f6-5883ca5035ad is not online. Triggering retrieval from long term archive.
# Product 73a70926-217f-4885-99f2-cfa22d669b09 is not online. Triggering retrieval from long term archive.
# Product b5bec48e-cb3e-4d58-95e7-3175c240c3cd is not online. Triggering retrieval from long term archive.
# Product 2dfb2b4e-8b79-48ef-9590-f11e691274ce is not online. Triggering retrieval from long term archive.
# Product 36223aa9-a261-49a9-abaf-b0ee5f14be90 is not online. Triggering retrieval from long term archive.
# Product e0892b55-a065-4d9c-8a37-0e26251009dc is not online. Triggering retrieval from long term archive.
# Product adf51190-656c-47f3-a054-d262f2695891 is not online. Triggering retrieval from long term archive.
# Product ba3473e7-473e-4a13-85e6-c668012afa5e is not online. Triggering retrieval from long term archive.
# ...

# %%
#convert to dataframe
products_df = api.to_dataframe(products)

# %%
#convert to geodataframe
#import geopandas
#products_gdf = api.to_geodataframe(products)

# %%
products_df.shape
# Out:
# (29, 36)

# %%
products_df
# Out:
#                                                                                   title  \
# f1d64049-18cd-45db-b844-09b55ece2b5a  S1A_IW_SLC__1SDV_20190923T174612_20190923T1746...
# 137e2f20-e04d-4930-b0a1-42e15e0f1676  S1A_IW_SLC__1SDV_20190923T174638_20190923T1747...
# 72a64ab7-a75b-481a-a97c-49a581d4be82  S1A_IW_GRDH_1SDV_20190923T174639_20190923T1747...
# 9320c6be-ef55-4fea-8f4b-949ee78cfcd8  S1A_IW_RAW__0SDV_20190923T174635_20190923T1747...
# c44d2efc-e93b-4fd5-b63c-0fe2c8899f69  S1A_WV_OCN__2SSV_20190923T051535_20190923T0522...
# ...                                                                                 ...
# 58bf7250-9d26-4da6-ac65-3149426d3b53  S1A_WV_SLC__1SSV_20190607T051529_20190607T0521...
# 1ac28533-25da-4abf-88c0-3b536d02d069  S1A_IW_SLC__1SDV_20190602T173818_20190602T1738...
# 79dafb19-bf32-4007-acd8-718992bffd78  S1A_IW_GRDH_1SDV_20190602T173820_20190602T1738...
# 65cf8ed2-f64d-40c1-b765-83e0e8adf476  S1A_IW_RAW__0SDV_20190602T173841_20190602T1739...
# ...

# %%
for product in products:
    #print(product)
    p_data = api.get_product_odata(product)
    #print(p_data)
    print(p_data['title'])
    break
# Out:
# S1A_IW_SLC__1SDV_20190923T174612_20190923T174640_029152_034F51_813B
